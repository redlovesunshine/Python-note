# %% [markdown]
# # 打開 jupyter 必做!
#
# ## 數據分析標準動作
#
# %matplotlib inline             #意思是如果有圖顯示，則直接在這裡顯示，不用再多開一個視窗

# %%
# %matplotlib inline  
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3,-5,6,7,9,10])

# %%
plt.plot(np.random.randn(100)) #生成 100 個常態分布的圖

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# 可以擅用 tab 鍵
